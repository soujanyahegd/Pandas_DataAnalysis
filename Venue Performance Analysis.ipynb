# %% [markdown]
# <div style="background-color: #655765; color: white; padding: 10px; border: 2px solid #655765;">
#
# # Load Data
#
# </div>

# %% [markdown]
# <div style="background-color: whitesmoke; padding: 10px;border: 2px solid #000000;">
#
# ## Question 1 - Import the Performances_By_Venue_Zip.csv file
#
#  - Load the data into a New Pandas DataFrame
#  - ... means you need to fill in with code
#
#
# </div>

# %%
#Import Python Libraries
import pandas as pd #data analysis library
import numpy as np #use for working with numeric/math functions

# Create a blank DataFrame named df_performances
df_performances = pd.DataFrame()

# Load data from the CSV file into the DataFrame 
csv_file = "Performances_By_Venue_Zip.csv"
df_performances = pd.read_csv(csv_file)

# Print the results of your dataframe
df_performances
# Out:
#                                            Venue_Name STATE_ABBR  ZIP_CODE  \
# 0   Patton Road Bar and Grill                     ...         AL     36108
# 1   Sixth Road Bar                                ...         AL     36875
# 2   Amar's Bar and Grill                          ...         AR     72901
# 3   Ayaka's on Henry                              ...         AR     71854
# 4   Jessica's on Wilson                           ...         AR     72823
# ..                                                ...        ...       ...
# 95  Henry Boulevard Bar                           ...         WA     99208
# 96  Jessica's on Monroe                           ...         WA     98948
# 97  Nicholas's on Arthur                          ...         WA     98362
# 98  Chan's on Lemon                               ...         WI     53545
# 99  Cristina's on Henry                           ...         WI     53208
#
# ...

# %%
#inspect your dataframe
df_performances.info()

# finding number of rows and coloumns
df_performances.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Venue_Name              100 non-null    object
#  1   STATE_ABBR              100 non-null    object
#  2   ZIP_CODE                100 non-null    int64
#  3   Total_Revenue_Amount    100 non-null    float64
#  4   Average_Revenue_Amount  100 non-null    float64
#  5   Unique_Performances     100 non-null    int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 4.8+ KB
# (100, 6)

# %%
#use "dtypes" to review the column names and their data types

df_performances.dtypes
# Out:
# Venue_Name                 object
# STATE_ABBR                 object
# ZIP_CODE                    int64
# Total_Revenue_Amount      float64
# Average_Revenue_Amount    float64
# Unique_Performances         int64
# dtype: object

# %%
#use "describe()" to review statical information on your DataFrame

df_performances.describe(include = 'all')
# Out:
#                                                Venue_Name STATE_ABBR  \
# count                                                 100        100
# unique                                                 97         37
# top     Amar's Bar and Grill                          ...         NY
# freq                                                    2          9
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#             ZIP_CODE  Total_Revenue_Amount  Average_Revenue_Amount  \
# count     100.000000          1.000000e+02              100.000000
# ...

# %% [markdown]
# <div style="background-color: #655765; color: white; padding: 10px; border: 2px solid #655765;">
#
# # Cleaning the Data
#
# </div>

# %%
#Step 1 check for missing values:

df_performances.isnull().sum()
# Out:
# Venue_Name                0
# STATE_ABBR                0
# ZIP_CODE                  0
# Total_Revenue_Amount      0
# Average_Revenue_Amount    0
# Unique_Performances       0
# dtype: int64

# %% [markdown]
# <div style="background-color: whitesmoke; padding: 10px;border: 2px solid #000000;">
#
# ## Question 2 - Import the Zip_Code.json file
#
#  - Load the data into a New Pandas DataFrame
#  - ... means you need to fill in with code
#
# </div>

# %%
# Create a blank DataFrame named df_zip_info
df_zip_info = pd.DataFrame()

# Load data from the JSON Zip Code file into the DataFrame 
df_zip_info = pd.read_json("Zip_Code.json", lines=True)

# %%
# Print the results of your dataframe
df_zip_info
# Out:
#        index  Total_Population  Median_Age  Median_Household_Income  \
# 0          0             11206        40.7                  74518.0
# 1          1              4084        49.7                  61898.0
# 2          2             20191        41.4                  70585.0
# 3          3             23029        28.9                  42094.0
# 4          4             12678        37.3                  80125.0
# ...      ...               ...         ...                      ...
# 33115  33115             12237        35.3                  61642.0
# 33116  33116              3959        46.7                 118264.0
# 33117  33117               378        36.6                  60625.0
# 33118  33118              2106        46.8                  45292.0
# 33119  33119              4900        30.7                  99419.0
#
#        Male_Population  Female_Population  White_Population  \
# 0                 5759               5447             10881
# ...

# %%
#inspect your dataframe

df_zip_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33120 entries, 0 to 33119
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   index                        33120 non-null  int64
#  1   Total_Population             33120 non-null  int64
#  2   Median_Age                   33120 non-null  float64
#  3   Median_Household_Income      33085 non-null  float64
#  4   Male_Population              33120 non-null  int64
#  5   Female_Population            33120 non-null  int64
#  6   White_Population             33120 non-null  int64
#  7   African_American_Population  33120 non-null  int64
#  8   Asian_Population             33120 non-null  int64
#  9   Number_of_Households         33120 non-null  int64
#  10  Number_of_Housing_Units      33120 non-null  int64
#  11  No_High_School_Diploma       33120 non-null  int64
#  12  Bachelor_s_Degree            33120 non-null  int64
# ...

# %%
df_zip_info.dtypes
# Out:
# index                            int64
# Total_Population                 int64
# Median_Age                     float64
# Median_Household_Income        float64
# Male_Population                  int64
# Female_Population                int64
# White_Population                 int64
# African_American_Population      int64
# Asian_Population                 int64
# Number_of_Households             int64
# Number_of_Housing_Units          int64
# No_High_School_Diploma           int64
# Bachelor_s_Degree                int64
# Unemployed_Population          float64
# Median_Home_Value                int64
# Below_Poverty_Level            float64
# Median_Gross_Rent                int64
# Population_Age_10_14             int64
# Population_Age_40_44             int64
# Gini_Index                     float64
# NAME                            object
# state                            int64
# zip_code_tabulation_area         int64
# dtype: object

# %%
df_zip_info.describe(include='all')
# Out:
#                index  Total_Population    Median_Age  Median_Household_Income  \
# count   33120.000000      33120.000000  3.312000e+04             3.308500e+04
# unique           NaN               NaN           NaN                      NaN
# top              NaN               NaN           NaN                      NaN
# freq             NaN               NaN           NaN                      NaN
# mean    16559.500000       9851.278865 -1.135262e+07            -4.415424e+07
# std      9561.064794      14614.856872  8.625416e+07             1.659040e+08
# min         0.000000          0.000000 -6.666667e+08            -6.666667e+08
# 25%      8279.750000        705.000000  3.660000e+01             4.059500e+04
# 50%     16559.500000       2803.500000  4.170000e+01             5.250000e+04
# 75%     24839.250000      13378.500000  4.710000e+01             6.691000e+04
# max     33119.000000     122814.000000  9.830000e+01             2.500010e+05
#
# ...

# %%
default_Household_Income = '0'
df_zip_info['Median_Household_Income'] = df_zip_info['Median_Household_Income'].fillna(default_Household_Income).astype(object)

df_zip_info.isnull().sum()
# Out:
# index                           0
# Total_Population                0
# Median_Age                      0
# Median_Household_Income         0
# Male_Population                 0
# Female_Population               0
# White_Population                0
# African_American_Population     0
# Asian_Population                0
# Number_of_Households            0
# Number_of_Housing_Units         0
# No_High_School_Diploma          0
# Bachelor_s_Degree               0
# Unemployed_Population          35
# Median_Home_Value               0
# Below_Poverty_Level            35
# Median_Gross_Rent               0
# Population_Age_10_14            0
# Population_Age_40_44            0
# Gini_Index                     35
# NAME                            0
# state                           0
# zip_code_tabulation_area        0
# dtype: int64

# %%
default_Unemployed_Population = '0'
df_zip_info['Unemployed_Population'] = df_zip_info['Unemployed_Population'].fillna(default_Unemployed_Population).astype(object)

default_Below_Poverty_Level = '0'
df_zip_info['Below_Poverty_Level'] = df_zip_info['Below_Poverty_Level'].fillna(default_Below_Poverty_Level).astype(object)

default_Gini_Index = '0'
df_zip_info['Gini_Index'] = df_zip_info['Gini_Index'].fillna(default_Gini_Index).astype(object)


df_zip_info.isnull().sum()
# Out:
# index                          0
# Total_Population               0
# Median_Age                     0
# Median_Household_Income        0
# Male_Population                0
# Female_Population              0
# White_Population               0
# African_American_Population    0
# Asian_Population               0
# Number_of_Households           0
# Number_of_Housing_Units        0
# No_High_School_Diploma         0
# Bachelor_s_Degree              0
# Unemployed_Population          0
# Median_Home_Value              0
# Below_Poverty_Level            0
# Median_Gross_Rent              0
# Population_Age_10_14           0
# Population_Age_40_44           0
# Gini_Index                     0
# NAME                           0
# state                          0
# zip_code_tabulation_area       0
# dtype: int64

# %% [markdown]
# <div style="background-color: #655765; color: white; padding: 10px; border: 2px solid #655765;">
#
# # JOIN Data
#
# </div>

# %% [markdown]
# <div style="background-color: whitesmoke; padding: 10px;border: 2px solid #000000;">
#
# ## Question 3 - Merge/JOIN the two dataframes
#
#  - Merge the two DataFrames together into a New DataFrame using INNER
#  - Use Zip Code fields from each of the the Data Frames as your KEY/LINK
#  - ... means you need to fill in with code
#
# </div>

# %%
# Perform the join between df_performances and df_zip_info dataframes
df_performance_zip_stats = pd.merge(df_performances, df_zip_info,
                                    left_on='ZIP_CODE',
                                    right_on='zip_code_tabulation_area',
                                    how='inner')
df_performance_zip_stats
# Out:
#                                            Venue_Name STATE_ABBR  ZIP_CODE  \
# 0   Patton Road Bar and Grill                     ...         AL     36108
# 1   Sixth Road Bar                                ...         AL     36875
# 2   Amar's Bar and Grill                          ...         AR     72901
# 3   Ayaka's on Henry                              ...         AR     71854
# 4   Jessica's on Wilson                           ...         AR     72823
# ..                                                ...        ...       ...
# 93  Henry Boulevard Bar                           ...         WA     99208
# 94  Jessica's on Monroe                           ...         WA     98948
# 95  Nicholas's on Arthur                          ...         WA     98362
# 96  Chan's on Lemon                               ...         WI     53545
# 97  Cristina's on Henry                           ...         WI     53208
#
# ...

# %%
# Print the results of your dataframe
df_performance_zip_stats
# Out:
#                                            Venue_Name STATE_ABBR  ZIP_CODE  \
# 0   Patton Road Bar and Grill                     ...         AL     36108
# 1   Sixth Road Bar                                ...         AL     36875
# 2   Amar's Bar and Grill                          ...         AR     72901
# 3   Ayaka's on Henry                              ...         AR     71854
# 4   Jessica's on Wilson                           ...         AR     72823
# ..                                                ...        ...       ...
# 93  Henry Boulevard Bar                           ...         WA     99208
# 94  Jessica's on Monroe                           ...         WA     98948
# 95  Nicholas's on Arthur                          ...         WA     98362
# 96  Chan's on Lemon                               ...         WI     53545
# 97  Cristina's on Henry                           ...         WI     53208
#
# ...

# %% [markdown]
# <div style="background-color: #655765; color: white; padding: 10px; border: 2px solid #655765;">
#
# # Visualize Data
#
# </div>

# %% [markdown]
# <div style="background-color: whitesmoke; padding: 10px;border: 2px solid #000000;">
#
# ## Question 4 - Create a Pivot Table using your df_performance_zip_stats DataFrame
#
#  - you may want to go back and reference the PowerPoint and your Assignment for Lesson 1e
#  - you may want to create a binned field or grouper field to make the chart more readable
#  - SORT your Pivot Table
#  - FORMAT your Pivot Table
#
# </div>

# %%
#Create a new column of your choice using either the bin_edges and bin lables approach

# Create a new column using bin_edges and bin lables
# create the bin for lables
bins = [0, 3000000, 6000000, 9000000,float('inf')]

# defining the lable for each bin
labels = ['0 to 3,000,000', '3,000,000 to 6,000,000', '6,000,000 to 9,000,000', '9,000,000 plus']

#create TotalRev_Buckets column
df_performance_zip_stats['TotalRev_Buckets'] = pd.cut(df_performance_zip_stats['Total_Revenue_Amount'], bins=bins, labels=labels, right=False)
df_performance_zip_stats
# Out:
#                                            Venue_Name STATE_ABBR  ZIP_CODE  \
# 0   Patton Road Bar and Grill                     ...         AL     36108
# 1   Sixth Road Bar                                ...         AL     36875
# 2   Amar's Bar and Grill                          ...         AR     72901
# 3   Ayaka's on Henry                              ...         AR     71854
# 4   Jessica's on Wilson                           ...         AR     72823
# ..                                                ...        ...       ...
# 93  Henry Boulevard Bar                           ...         WA     99208
# 94  Jessica's on Monroe                           ...         WA     98948
# 95  Nicholas's on Arthur                          ...         WA     98362
# 96  Chan's on Lemon                               ...         WI     53545
# 97  Cristina's on Henry                           ...         WI     53208
#
# ...

# %%
totalRev_Buckets_sum = df_performance_zip_stats.groupby('TotalRev_Buckets').size().reset_index(name = 'Record_Count')

totalRev_Buckets_sum
# Out:
#          TotalRev_Buckets  Record_Count
# 0          0 to 3,000,000             0
# 1  3,000,000 to 6,000,000             9
# 2  6,000,000 to 9,000,000            89
# 3          9,000,000 plus             0

# %%
bins = [0, 10000, 50000, 100000, float('inf')]
labels = ['Low', 'Medium', 'High', 'Very High']
df_performance_zip_stats['Average_Revenue_Bin'] = pd.cut(df_performance_zip_stats['Average_Revenue_Amount'], bins=bins, labels=labels)

df_performance_zip_stats
# Out:
#                                            Venue_Name STATE_ABBR  ZIP_CODE  \
# 0   Patton Road Bar and Grill                     ...         AL     36108
# 1   Sixth Road Bar                                ...         AL     36875
# 2   Amar's Bar and Grill                          ...         AR     72901
# 3   Ayaka's on Henry                              ...         AR     71854
# 4   Jessica's on Wilson                           ...         AR     72823
# ..                                                ...        ...       ...
# 93  Henry Boulevard Bar                           ...         WA     99208
# 94  Jessica's on Monroe                           ...         WA     98948
# 95  Nicholas's on Arthur                          ...         WA     98362
# 96  Chan's on Lemon                               ...         WI     53545
# 97  Cristina's on Henry                           ...         WI     53208
#
# ...

# %%
bins = [0, 5, 15, 30, float('inf')]
labels = ['Rare', 'Occasional', 'Frequent', 'Very Frequent']
df_performance_zip_stats['Performance_Bin'] = pd.cut(df_performance_zip_stats['Unique_Performances'], bins=bins, labels=labels)

df_performance_zip_stats
# Out:
#                                            Venue_Name STATE_ABBR  ZIP_CODE  \
# 0   Patton Road Bar and Grill                     ...         AL     36108
# 1   Sixth Road Bar                                ...         AL     36875
# 2   Amar's Bar and Grill                          ...         AR     72901
# 3   Ayaka's on Henry                              ...         AR     71854
# 4   Jessica's on Wilson                           ...         AR     72823
# ..                                                ...        ...       ...
# 93  Henry Boulevard Bar                           ...         WA     99208
# 94  Jessica's on Monroe                           ...         WA     98948
# 95  Nicholas's on Arthur                          ...         WA     98362
# 96  Chan's on Lemon                               ...         WI     53545
# 97  Cristina's on Henry                           ...         WI     53208
#
# ...

# %%
regions = {
    'NY': 'Northeast', 'CA': 'West', 'TX': 'South', 'FL': 'South', 'PA': 'Northeast', 'IL': 'Midwest', 
    'OH': 'Midwest', 'GA': 'South', 'NC': 'South', 'MI': 'Midwest', 'NJ': 'Northeast', 'VA': 'South', 
    'WA': 'West', 'AZ': 'West', 'MA': 'Northeast', 'TN': 'South', 'IN': 'Midwest', 'MO': 'Midwest', 
    'MD': 'Northeast', 'WI': 'Midwest', 'CO': 'West', 'MN': 'Midwest', 'AL': 'South', 'LA': 'South', 
    'KY': 'South', 'OR': 'West', 'OK': 'South', 'SC': 'South', 'KS': 'Midwest', 'NE': 'Midwest', 
    'UT': 'West', 'IA': 'Midwest', 'NV': 'West', 'CT': 'Northeast', 'MS': 'South', 'AR': 'South', 
    'NM': 'West', 'ID': 'West', 'HI': 'West', 'MT': 'West', 'WY': 'West', 'DE': 'Northeast', 'AK': 'West', 
    'SD': 'Midwest', 'ND': 'Midwest', 'VT': 'Northeast', 'RI': 'Northeast', 'ME': 'Northeast', 'DC': 'Northeast', 
    'PR': 'South'
}

# Assuming 'df' is your DataFrame and 'STATE_ABBR' is the column with state abbreviations
df_performance_zip_stats['Region'] = df_performance_zip_stats['STATE_ABBR'].map(regions)
df_performance_zip_stats
# Out:
#                                            Venue_Name STATE_ABBR  ZIP_CODE  \
# 0   Patton Road Bar and Grill                     ...         AL     36108
# 1   Sixth Road Bar                                ...         AL     36875
# 2   Amar's Bar and Grill                          ...         AR     72901
# 3   Ayaka's on Henry                              ...         AR     71854
# 4   Jessica's on Wilson                           ...         AR     72823
# ..                                                ...        ...       ...
# 93  Henry Boulevard Bar                           ...         WA     99208
# 94  Jessica's on Monroe                           ...         WA     98948
# 95  Nicholas's on Arthur                          ...         WA     98362
# 96  Chan's on Lemon                               ...         WI     53545
# 97  Cristina's on Henry                           ...         WI     53208
#
# ...

# %%
# Create the pivot table
pivot_table = df_performance_zip_stats.pivot_table(index=['Region'],
                                    values=['Average_Revenue_Amount',
                                            'Unique_Performances',
                                            'Total_Population'],
                                    aggfunc={'Average_Revenue_Amount':'sum', 
                                            'Unique_Performances': 'sum',
                                             'Total_Population': 'sum'})

pivot_table['Average_Revenue_Per_Performance'] = pivot_table['Average_Revenue_Amount'] / pivot_table['Unique_Performances']
pivot_table


# Renaming the columns
pivot_table.columns = ['Total Average Revenue', 'Total Population', 'Unique Performance','Avg Revenue per Performance']
pivot_table

# Sort the pivot table
pivot_table_sorted = pivot_table.sort_values(by='Total Average Revenue', ascending=False)
pivot_table_sorted


# Format columns 
pivot_table['Total Average Revenue'] = pivot_table['Total Average Revenue'].apply('${:,.2f}'.format)
pivot_table['Avg Revenue per Performance'] = pivot_table['Avg Revenue per Performance'].apply('${:,.2f}'.format)
pivot_table['Total Population'] = pivot_table['Total Population'].astype(int).map('{:,}'.format)
pivot_table['Unique Performance'] = pivot_table['Unique Performance'].astype(int).map('{:,}'.format)

pivot_table
# Out:
#           Total Average Revenue Total Population Unique Performance  \
# Region
# Midwest             $236,574.96          625,277             15,756
# Northeast           $270,109.53          941,205             16,833
# South               $293,921.72          608,772             19,145
# West                $178,007.28          611,072             11,747
#
#           Avg Revenue per Performance
# Region
# Midwest                        $15.01
# Northeast                      $16.05
# South                          $15.35
# West                           $15.15

# %%
styled_pivot = pivot_table.style.set_table_styles(
    {
        'Total Average Revenue': [{'selector': 'th', 'props': 'background-color: lightblue; color: black;'}],
        'Total Population': [{'selector': 'th', 'props': 'background-color: lightblue; color: black;'}],
        'Unique Performance': [{'selector': 'th', 'props': 'background-color: lightblue; color: black;'}],
        'Avg Revenue per Performance': [{'selector': 'th', 'props': 'background-color: lightblue; color: black;'}]    
    }
)

styled_pivot
# Out:
# <style type="text/css">
# #T_46431 th.col0 {
#   background-color: lightblue;
#   color: black;
# }
# #T_46431 th.col1 {
#   background-color: lightblue;
#   color: black;
# }
# #T_46431 th.col2 {
#   background-color: lightblue;
#   color: black;
# }
# #T_46431 th.col3 {
#   background-color: lightblue;
#   color: black;
# }
# </style>
# <table id="T_46431">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46431_level0_col0" class="col_heading level0 col0" >Total Average Revenue</th>
#       <th id="T_46431_level0_col1" class="col_heading level0 col1" >Total Population</th>
#       <th id="T_46431_level0_col2" class="col_heading level0 col2" >Unique Performance</th>
#       <th id="T_46431_level0_col3" class="col_heading level0 col3" >Avg Revenue per Performance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
# ...

# %% [markdown]
# <div style="background-color: whitesmoke; padding: 10px;border: 2px solid #000000;">
#
# ## Question 5 - Using Matplotlib or Seaborn, create a chart of your choice using your df_performance_zip_stats DataFrame
#
#  - you may want to go back and reference the PowerPoint and your Assignment for Lesson 1e
#  - you may want to create a binned field or grouper field to make the chart more readable
#
# </div>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the DataFrame with your data
data = {
    'Region': ['Midwest', 'Northeast', 'South', 'West'],
    'Total Avg Revenue ($)': [236574.96, 270109.53, 293921.72, 178007.28],
    'Total Population': [625277, 941205, 608772, 611072],
    'Unique Performance': [15756, 16833, 19145, 11747],
    'Avg Revenue/Performance ($)': [15.01, 16.05, 15.35, 15.15]
}
df = pd.DataFrame(data)

# Set the 'Region' as the index to display regions as rows
df.set_index('Region', inplace=True)

#Plot the heatmap
plt.figure(figsize=(18, 10))  # Adjust the size as needed
sns.heatmap(df, annot=True, cmap='YlOrBr', fmt=".2f", linewidths=0.5, cbar_kws={'label': 'Color Code with Numbers'})

# Adding title and labels
plt.title('Heatmap of Metrics by Region', fontsize=25, pad=25)
plt.xlabel('Metrics', fontsize=20)
plt.ylabel('Region', fontsize=20)

# Change the size of tick labels
plt.xticks(fontsize=12)  # Change x-axis tick label size
plt.yticks(fontsize=12)  # Change y-axis tick label size

# Show the plot
plt.show()
